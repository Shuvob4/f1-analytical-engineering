# %% [markdown]
# # OpenF1 API — Source System Exploration
# **Day 3 | F1 Analytical Engineering Platform**
#
# ## Purpose
# Profile the OpenF1 REST API before writing any ingestion code.
# Understand schemas, data quality, pagination, and edge cases.
#
# ## Endpoints Under Investigation
# - `/sessions` — race weekend metadata
# - `/laps` — per-lap timing data
# - `/position` — car position on track
# - `/intervals` — gaps between drivers

# %%
import httpx
import pandas as pd
import json

BASE_URL = "https://api.openf1.org/v1"

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 50)
